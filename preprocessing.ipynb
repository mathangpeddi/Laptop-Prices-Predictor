# %% [markdown]
# # Web Scraping flipkart.com
# This is the Flipkart website comprising of different laptops. This page contains the details of 24 laptops. So now looking at this, we try to extract the different features of the laptops such as the description of the laptop (model name along with the specification of the laptop), Name of the Processor, Type of Processor, RAM, Operating System, Disk Drive Storage, Display, Warranty, Ratings, and Price. So we extract the data from 7 pages so our dataset consists of information the 168 distinct laptops.<br>
# Link to my article: https://towardsdatascience.com/learn-web-scraping-in-15-minutes-27e5ebb1c28e

# %% [markdown]
# # Data Collection

# %%
from bs4 import BeautifulSoup # Importing the BeautifulSoup package
import requests # Importing requests library
import csv
import pandas as pd

# %%
req = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1") # Requesting the content of the URL
content = req.content # Getting the content

# %%
soup = BeautifulSoup(content,'html.parser') # Here we need to specify the content variable and the parser which is the HTML parser
# So now soup is a variable of the BeautifulSoup object of our parsed HTML

# %%
print(soup.prettify()) # Displays the whole code of the website
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.21be2e.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
#    <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#    <!-- Appple Touch Icons -->
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#    <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
#    <!-- Twitter Meta Data -->
#    <meta content="app" name="twitter:card"/>
#    <meta content="@flipkart" name="twitter:site"/>
#    <meta content="@flipkart" name="twitter:creator"/>
#    <meta content="Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="twitter:title"/>
#    <meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/>
#    <meta content="in" name="twitter:app:country"/>
#    <meta content="Flipkart" name="al:ios:app_name"/>
#    <meta content="742044692" name="al:ios:app_store_id"/>
#    <meta content="Flipkart" name="twitter:app:name:iphone"/>
#    <meta content="742044692" name="twitter:app:id:iphone"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/>
#    <meta content="Flipkart" name="twitter:app:name:ipad"/>
#    <meta content="742044692" name="twitter:app:id:ipad"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/>
#    <meta content="Flipkart" name="twitter:app:name:googleplay"/>
#    <meta content="com.flipkart.android" name="twitter:app:id:googleplay"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/>
#    <style>
#     #container {
# 			height: 100%;
# 		}
#    </style>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/runtime.7298d81b.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.chunk.817b8b06.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_modules.chunk.8f7ab355.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app_common.chunk.8a665b50.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app.chunk.fb0d58fc.js">
#    </script>
#    <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/MultiWidgetBase.chunk.8fd37f.css" rel="stylesheet"/>
#    <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/Browse.chunk.4dadf6.css" rel="stylesheet"/>
#    <title>
#     Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com
#    </title>
#    <meta content="Laptops - Buy Products Online at Best Price in India - All Categories | Flipkart.com" name="og_title" property="og:title">
#     <meta content="Laptops" name="Keywords">
#      <meta content="Laptops - Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" name="Description">
#       <meta content="Laptops - Buy Products Online at Best Price in India. India's Leading E-commerce Company - Free Home Delivery - All Categories | Flipkart.com" property="og:description">
#        <meta content="noindex" name="robots">
#         <meta content="F4EEB3A0AFFDD385992A06E6920C0AC3" name="msvalidate.01">
#          <!--[if IE 9 ]>
# 	<script nonce="703819325761862535">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
#          <!--[if !IE]><!-->
#          <script nonce="703819325761862535">
#           if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}
#          </script>
#          <!--<![endif]-->
#          <script id="jsonLD" nonce="703819325761862535" type="application/ld+json">
#           {}
#          </script>
#          <script nonce="703819325761862535">
#           !function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#          </script>
#          <script nonce="703819325761862535">
#           if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#          </script>
#          <link href="https://www.flipkart.com/search?q=laptops&amp;otracker=search&amp;otracker1=search&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;page=2" id="next-page-link-tag" rel="next"/>
#          <link href="https://www.flipkart.com/amp/search?q=laptops&amp;otracker=search&amp;otracker1=search&amp;marketplace=FLIPKART&amp;as-show=on&amp;as=off&amp;page=1" rel="amphtml"/>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body>
#   <div id="container">
#    <div data-reactroot="">
#     <div class="_3ybBIU">
#      <div class="_1tz-RS">
#       <div class="_1S7OK2">
#       </div>
#       <div class="_3pNZKl">
#        <div class="_1T-JyI">
#         <div class="_3dGepu">
#          <a href="/">
#           <img alt="Flipkart" class="_1e_EAo" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png" title="Flipkart" width="75"/>
#          </a>
#          <a class="_33x-Wq" href="/plus">
#           Explore
#           <!-- -->
#           <span class="_2Ky4Ru">
#            Plus
#           </span>
#           <img src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png" width="10"/>
#          </a>
#         </div>
#        </div>
#        <div class="Y5-ZPI">
#         <form action="/search" class="_1WMLwI header-form-search" method="GET">
#          <div class="col-12-12 _2tVp4j">
#           <div class="O8ZS_U">
#            <input autocomplete="off" class="LM6RPg" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="laptops"/>
#           </div>
#           <button class="vh79eN" type="submit">
#            <svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
#             <g fill="#2874F1" fill-rule="evenodd">
#              <path class="_2BhAHa" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
#              </path>
#              <path class="_2BhAHa" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
#              </path>
#             </g>
#            </svg>
#           </button>
#           <input name="otracker" type="hidden" value="search"/>
#           <input name="otracker1" type="hidden" value="search"/>
#           <input name="marketplace" type="hidden" value="FLIPKART"/>
#           <input name="as-show" type="hidden" value="off"/>
#           <input name="as" type="hidden" value="off"/>
#          </div>
#          <ul class="col-12-12 _1PBbw8">
#          </ul>
#         </form>
#        </div>
#        <div class="_1jA3uo _34niwY">
#         <div class="dHGf8H">
#          <div class="_1jcwFN _3dmQRh">
#           <div>
#            <a class="_3Ep39l" href="/account/login?ret=/search%3Fq%3Dlaptops%26otracker%3Dsearch%26otracker1%3Dsearch%26marketplace%3DFLIPKART%26as-show%3Don%26as%3Doff%26page%3D1">
#             Login
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="_1jA3uo">
#         <div class="dHGf8H">
#          <div class="_1jcwFN _3dmQRh">
#           <div>
#            <div class="_2aUbKa">
#             <!-- -->
#             More
#             <!-- -->
#            </div>
#           </div>
#          </div>
#          <svg class="_34Yjv1" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg">
#           <path class="_14jSvk" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#           </path>
#          </svg>
#         </div>
#        </div>
#        <div class="_1jA3uo">
#         <div class="_1jcwFN">
#          <div class="_3K4_9Q">
#           <a class="_3ko_Ud" href="/viewcart?otracker=Cart_Icon_Click">
#            <svg class="_2fcmoV" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg">
#             <path class="_2JpNOH" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
#             </path>
#            </svg>
#            <span>
#             Cart
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="_1S7OK2">
#       </div>
#      </div>
#      <div class="_2hlh_L">
#      </div>
#     </div>
#     <div class="zi6sUf">
#     </div>
#     <div class="t-0M7P _2doH3V">
#      <div class="_1VV5Cf _1QHAXj">
#       <div class="_1SFos- _14bj8B" style="transform:scaleX(0)">
#       </div>
#      </div>
#      <div class="_3e7xtJ">
#       <div class="_1HmYoV hCUpcT">
#        <div class="_1HmYoV _35HD7C" style="flex:0 0 280px;max-width:280px;padding:0px 10px 0px 0px">
#         <div class="bhgxx2 col-12-12" style="padding:0px 0px 10px 0px">
#          <a class="_3udMMB _2ULE1d" href="/acer-aspire-7-core-i5-9th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-gtx-1650-a715-75g-50sa-gaming-laptop/p/itmff1cbf710ce62?pid=COMFR6AANWZVZM8Y&amp;otracker=sp_browse_announcement_search.flipkart.com">
#           <div class="_3JlYXy" style="padding-top:53.57%">
#            <div class="_2tnqd0 _3ZJShS" style="padding-top:53.57%">
#             <img alt="Acer Aspire 7 " class="_232NW7 _2MPLm_"/>
#             <img alt="Acer Aspire 7 " class="_2VeolH _3I5S6S _20er9E" src="https://rukminim1.flixcart.com/flap/100/54/image/a0b287123ea3a8bc.jpg?q=50"/>
#            </div>
#           </div>
#           <div class="yQXdAl">
#            <div class="_3i65ul">
#             Acer Aspire 7
#            </div>
#            <div class="_2mPS7z">
#             4 GB Graphics | NVIDIA Geforce GTX 1650
#            </div>
#           </div>
#          </a>
#         </div>
#         <div class="_1HmYoV _35HD7C col-12-12">
#          <div class="bhgxx2 col-12-12">
#           <div class="_1YuAuf">
#            <section class="xeGmCJ D_NGuZ">
#             <div class="_1iMC4O">
#              <div class="D0YrLF">
#               <span>
#                Filters
#               </span>
#              </div>
#             </div>
#            </section>
#            <div class="_1AsMpB">
#             <section class="_3aoPnm">
#              <div class="_1-5MDT">
#               <span>
#                CATEGORIES
#               </span>
#              </div>
#              <div>
#               <div class="sUG0yY">
#                <span>
#                 <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                  <path class="zTtNVt" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                  </path>
#                 </svg>
#                </span>
#                <a class="_3O_Sek _32ZSYo" href="/computers/pr?sid=6bo&amp;q=laptops&amp;otracker=categorytree" title="Computers">
#                 Computers
#                </a>
#               </div>
#              </div>
#              <div>
#               <div class="sUG0yY">
#                <span>
#                 <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                  <path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                  </path>
#                 </svg>
#                </span>
#                <a class="_3XS1AH _32ZSYo" href="/laptops/pr?sid=6bo,b5g&amp;q=laptops&amp;otracker=categorytree" title="Laptops">
#                 Laptops
#                </a>
#               </div>
#              </div>
#             </section>
#            </div>
#            <section class="_1MCcAi D_NGuZ">
#             <div class="_1IqaqM _1iMC4O">
#              <div class="_2Bzspk D0YrLF">
#               <span>
#                Price
#               </span>
#              </div>
#             </div>
#             <div class="_1zXsFA">
#              <div class="_23Eu_p">
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#               <div class="HKK57-" style="height:0;width:0">
#               </div>
#              </div>
#             </div>
#             <div class="_1A0dov">
#              <div class="gl5Kwg">
#               <div class="_3G9WVX oVjMho">
#                <div class="_3aQU3C">
#                </div>
#               </div>
#               <div class="_3G9WVX _2N3EuE">
#                <div class="_3aQU3C">
#                </div>
#               </div>
#               <div class="_3QFE_k">
#               </div>
#               <div class="_3QFE_k _3bwhLT">
#               </div>
#              </div>
#              <div class="UkModz">
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:undefinedpx">
#                .
#               </div>
#               <div class="_3mWtXv" style="width:0px">
#                .
#               </div>
#              </div>
#             </div>
#             <div class="_3Uy12X">
#              <div class="_1qKb_B">
#               <select class="fPjUPw">
#                <option class="OMc8Rd" selected="" value="Min">
#                 Min
#                </option>
#                <option class="OMc8Rd" value="20000">
#                 ₹20000
#                </option>
#                <option class="OMc8Rd" value="30000">
#                 ₹30000
#                </option>
#                <option class="OMc8Rd" value="40000">
#                 ₹40000
#                </option>
#                <option class="OMc8Rd" value="50000">
#                 ₹50000
#                </option>
#                <option class="OMc8Rd" value="60000">
#                 ₹60000
#                </option>
#                <option class="OMc8Rd" value="75000">
#                 ₹75000
#                </option>
#               </select>
#              </div>
#              <div class="_2LchWD">
#               to
#              </div>
#              <div class="_1YoBfV">
#               <select class="fPjUPw">
#                <option class="OMc8Rd" value="20000">
#                 ₹20000
#                </option>
#                <option class="OMc8Rd" value="30000">
#                 ₹30000
#                </option>
#                <option class="OMc8Rd" value="40000">
#                 ₹40000
#                </option>
#                <option class="OMc8Rd" value="50000">
#                 ₹50000
#                </option>
#                <option class="OMc8Rd" value="60000">
#                 ₹60000
#                </option>
#                <option class="OMc8Rd" value="75000">
#                 ₹75000
#                </option>
#                <option class="OMc8Rd" selected="" value="Max">
#                 ₹75000+
#                </option>
#               </select>
#              </div>
#             </div>
#            </section>
#            <section class="D_NGuZ _1KDdN8">
#             <div class="_2kFyHg _1_fxb2">
#              <label>
#               <input class="_3uUUD5" readonly="" type="checkbox"/>
#               <div class="_1p7h2j _2irnD_">
#               </div>
#               <div class="_1GEhLw">
#                <div class="_2rIV_l">
#                 <img class="_2rIV_l" height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/>
#                </div>
#               </div>
#              </label>
#             </div>
#             <div class="_20yN1P">
#              <span class="question">
#               ?
#              </span>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Processor
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="Core i5">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Core i5
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Core i7">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Core i7
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Core i3">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Core i3
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Ryzen 7 Quad Core">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Ryzen 7 Quad Core
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Ryzen 5 Quad Core">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Ryzen 5 Quad Core
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Core i9">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Core i9
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="opNt-w _2Tprpw">
#               <span>
#                18 MORE
#               </span>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Brand
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="Apple">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Apple
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="HP">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    HP
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Dell">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Dell
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Lenovo">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Lenovo
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Asus">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Asus
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Acer">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Acer
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="opNt-w _2Tprpw">
#               <span>
#                11 MORE
#               </span>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Screen Size
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Operating System
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Dedicated Graphics Memory
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Hard Disk Capacity
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Processor Brand
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Discount
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Graphic Processor Name
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Touch Screen
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Ram Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Offers
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="Bank Offer">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Bank Offer
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="No Cost EMI">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    No Cost EMI
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="Special Price">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    Special Price
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Customer Ratings
#              </div>
#              <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_3mk-PQ">
#              <div class="_36jUgy">
#               <div class="_4IiNRh _2mtkou" title="4★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    4★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="3★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    3★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="2★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    2★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#               <div class="_4IiNRh _2mtkou" title="1★ &amp; above">
#                <div class="_2wQvxh _1WV8jE">
#                 <div class="_2kFyHg _2mtkou">
#                  <label>
#                   <input class="_3uUUD5" readonly="" type="checkbox"/>
#                   <div class="_1p7h2j">
#                   </div>
#                   <div class="_1GEhLw">
#                    1★ &amp; above
#                   </div>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               RAM Capacity
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Processor Generation
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Storage Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Graphic Processor Series
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               SSD Capacity
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Features
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Weight
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Usage
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               LifeStyle
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Graphics Memory Type
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#            <section class="_1gjf4c D_NGuZ">
#             <div class="_3xglSm _1iMC4O">
#              <div class="_2yccxO D0YrLF">
#               Availability
#              </div>
#              <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </section>
#           </div>
#          </div>
#          <div class="bhgxx2 col-12-12">
#           <a class="_2cPh2h" href="/buying-guide/laptops?sid=6bo,b5g&amp;otracker=bg_from_browse_lhs" title="Buying Guide">
#            <div>
#             <span>
#              Need help?
#             </span>
#            </div>
#            <div class="_3OzbwH">
#             <span>
#              Help me decide
#             </span>
#             <svg class="_1fiSL1" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#              <path class="_3fPZ07" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#              </path>
#             </svg>
#            </div>
#            <img alt="Buying Guide" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_48642c.png"/>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="_1HmYoV _35HD7C" style="flex-grow:1;overflow:auto">
#         <div class="_1HmYoV hCUpcT col-12-12" style="background-color:#ffffff;align-items:flex-end">
#          <div class="bhgxx2" style="flex-grow:1;overflow:auto">
#           <div class="_3UEiDE">
#            <div class="_1joEet">
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/">
#               Home
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/computers/pr?sid=6bo&amp;marketplace=FLIPKART">
#               Computers
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/laptops/pr?sid=6bo,b5g&amp;marketplace=FLIPKART">
#               Laptops
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#            </div>
#            <span class="_2yAnYN">
#             Showing 1 – 24 of 449 results for "
#             <span>
#              laptops
#             </span>
#             "
#            </span>
#            <div class="_3ywJNQ">
#             <span class="_3YmFT8">
#              Sort By
#             </span>
#             <div class="_1xHtJz xufquN">
#              Relevance
#             </div>
#             <div class="_1xHtJz">
#              Popularity
#             </div>
#             <div class="_1xHtJz">
#              Price -- Low to High
#             </div>
#             <div class="_1xHtJz">
#              Price -- High to Low
#             </div>
#             <div class="_1xHtJz">
#              Newest First
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="bhgxx2 col-12-12">
#          <div class="_3O0U0u">
#           <div data-id="COMFSKF9EMHCTN2Y" style="width:100%">
#            <div class="_1UoZlX">
#             <a class="_31qSD5" href="/asus-vivobook-15-ryzen-3-dual-core-4-gb-1-tb-hdd-windows-10-home-m509da-ej741t-laptop/p/itm3818c90283cd6?pid=COMFSKF9EMHCTN2Y&amp;lid=LSTCOMFSKF9EMHCTN2YYUZ02T&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=44a663ff-696e-4166-8380-dfcf65331722.COMFSKF9EMHCTN2Y.SEARCH&amp;ssid=u25cn91ow00000001596650814064&amp;qH=c06ea84a1e3dc3c6" rel="noopener noreferrer" target="_blank">
#              <div class="_3SQWE6">
#               <div class="_1OCn9C">
#                <div>
#                 <div class="_3BTv9X" style="height:200px;width:200px">
#                  <img alt="Asus VivoBook 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) M509DA-EJ741T Laptop" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
#                 </div>
#                </div>
#               </div>
#               <div class="_2lesQu">
#                <div class="_1O_CiZ">
#                 <span class="_1iHA1p">
#                  <div class="_2kFyHg">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                   </label>
#                  </div>
#                 </span>
#                 <label class="_10TB-Q">
#                  <span>
#                   Add to Compare
#                  </span>
#                 </label>
#                </div>
#               </div>
#               <div class="_3gDSOa _32A6AP">
#                <div class="DsQ2eg">
#                 <svg class="_2oLiqr" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#                  <path class="_35Y7Yo" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#                  </path>
#                 </svg>
#                </div>
#               </div>
#              </div>
#              <div class="_1-2Iqu row">
#               <div class="col col-7-12">
#                <div class="_3wU53n">
#                 Asus VivoBook 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) M509DA-EJ741T Laptop
#                </div>
#                <div class="niH0FQ">
#                 <span class="_2_KrJI" id="productRating_LSTCOMFSKF9EMHCTN2YYUZ02T_COMFSKF9EMHCTN2Y_">
#                  <div class="hGSR34">
#                   4.4
#                   <img class="_2lQ_WZ" src="..."/>
#                  </div>
#                 </span>
#                 <span class="_38sUEc">
#                  <span>
#                   <span>
#                    26 Ratings
#                   </span>
#                   <span class="_1VpSqZ">
#                    &amp;
#                   </span>
#                   <span>
#                    3 Reviews
#                   </span>
#                  </span>
#                 </span>
#                </div>
#                <div class="_3ULzGw">
#                 <ul class="vFw0gD">
#                  <li class="tVe95H">
#                   AMD Ryzen 3 Dual Core Processor
#                  </li>
#                  <li class="tVe95H">
#                   4 GB DDR4 RAM
#                  </li>
#                  <li class="tVe95H">
#                   64 bit Windows 10 Operating System
#                  </li>
#                  <li class="tVe95H">
#                   1 TB HDD
#                  </li>
#                  <li class="tVe95H">
#                   39.62 cm (15.6 inch) Display
#                  </li>
#                  <li class="tVe95H">
#                   My Asus, Splendid
#                  </li>
#                  <li class="tVe95H">
#                   1 Year Onsite Warranty
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <div class="col col-5-12 _2o7WAb">
#                <div class="_6BWGkk">
#                 <div class="_1uv9Cb">
# ...
#                 </circle>
#                 <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
#                 </path>
#                </g>
#               </svg>
#               <p class="_19inI8" id="review-34df3d89-52d8-44a5-99bd-378f4064c6fe">
#                <span>
#                 Certified Buyer
#                </span>
#               </p>
#               <p class="_3LYOAd">
#                11 days ago
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="_2Otlc1">
#           <div class="_1gH7KG">
#            Recent Review
#           </div>
#           <div class="col">
#            <div class="col _390CkK jc3RMt">
#             <div class="row">
#              <div class="hGSR34 E_uFuv">
#               5
#               <img class="_2lQ_WZ" src="..."/>
#              </div>
#              <p class="_2xg6Ul">
#               Worth every penny
#              </p>
#             </div>
#             <div class="row">
#              <div class="qwjRop">
#               <div>
#                <div class="">
#                 FLIPKART DELIVERY AS ALWAYS IS BEST.
#                 <br/>
#                 FIRST IMPRESSIONS ARE PREMIUM ENOUGH
#                 <br/>
#                 LOOKS ARE DECENT ENOUGH WITH GOOD PEACOCK BLUE COLOUR BUT LOOKS LITTLE PALE.
#                 <br/>
#                 OVERAL...
#                </div>
#                <span class="_1EPkIx">
#                 <span>
#                  Read full review
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#             <div class="row _2pclJg">
#              <div class="row">
#               <p class="_3LYOAd _3sxSiS">
#                Pavan kumar
#               </p>
#               <svg class="_3Zp_NJ" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg">
#                <g>
#                 <circle cx="6" cy="6" fill="#878787" r="6">
#                 </circle>
#                 <path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5">
#                 </path>
#                </g>
#               </svg>
#               <p class="_19inI8" id="review-617e187d-d64f-4f4f-9e05-6abd3248ab9d">
#                <span>
#                 Certified Buyer
#                </span>
#               </p>
#               <p class="_3LYOAd">
#                Today
#               </p>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="bhgxx2 col-12-12">
#       </div>
#      </div>
#     </div>
#     <footer class="HJlsB9">
#      <div class="TW4owM">
#       <div class="row">
#        <div class="col gu12 _2-C188">
#        </div>
#       </div>
#       <div>
#        <div class="_2NHqR1 row">
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           ABOUT
#          </div>
#          <a class="_287FRX" href="/helpcentre?otracker=undefined_footer_navlinks">
#           Contact Us
#          </a>
#          <a class="_287FRX" href="/about-us?otracker=undefined_footer_navlinks">
#           About Us
#          </a>
#          <a class="_287FRX" href="https://www.flipkartcareers.com/?otracker=undefined_footer_navlinks">
#           Careers
#          </a>
#          <a class="_287FRX" href="http://stories.flipkart.com/?otracker=undefined_footer_navlinks">
#           Flipkart Stories
#          </a>
#          <a class="_287FRX" href="/s/press?otracker=undefined_footer_navlinks">
#           Press
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           HELP
#          </div>
#          <a class="_287FRX" href="/pages/payments">
#           Payments
#          </a>
#          <a class="_287FRX" href="/pages/shipping">
#           Shipping
#          </a>
#          <a class="_287FRX" href="/helpcentre?catalog=55c9c6edb000002e002c1701&amp;view=CATALOG">
#           Cancellation &amp; Returns
#          </a>
#          <a class="_287FRX" href="/helpcentre?catalog=55c9c8e2b0000023002c1702&amp;view=CATALOG">
#           FAQ
#          </a>
#          <a class="_287FRX" href="https://seller.flipkart.com/fiv?otracker=undefined_footer_navlinks">
#           Report Infringement
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           POLICY
#          </div>
#          <a class="_287FRX" href="/pages/returnpolicy?otracker=undefined_footer_navlinks">
#           Return Policy
#          </a>
#          <a class="_287FRX" href="/pages/terms?otracker=undefined_footer_navlinks">
#           Terms Of Use
#          </a>
#          <a class="_287FRX" href="/pages/paymentsecurity?otracker=undefined_footer_navlinks">
#           Security
#          </a>
#          <a class="_287FRX" href="/pages/privacypolicy?otracker=undefined_footer_navlinks">
#           Privacy
#          </a>
#          <a class="_287FRX" href="/sitemap?otracker=undefined_footer_navlinks">
#           Sitemap
#          </a>
#          <a class="_287FRX" href="/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks">
#           EPR Compliance
#          </a>
#         </div>
#         <div class="_3qd5C5">
#          <div class="_18wTSA">
#           SOCIAL
#          </div>
#          <a class="_287FRX" href="https://www.facebook.com/flipkart">
#           Facebook
#          </a>
#          <a class="_287FRX" href="https://www.twitter.com/flipkart">
#           Twitter
#          </a>
#          <a class="_287FRX" href="https://www.youtube.com/flipkart">
#           YouTube
#          </a>
#         </div>
#         <div class="_3qd5C5 address">
#          <div class="_38DIp6">
#           <div class="_18wTSA">
#            <span>
#             Mail Us:
#            </span>
#           </div>
#           <div class="_2V3TtE">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _2V3TtE">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="_3qd5C5 address">
#          <div class="m6ABEi">
#           <div class="_18wTSA">
#            <span>
#             Registered Office Address:
#            </span>
#           </div>
#           <div class="_2V3TtE">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _2V3TtE">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Buildings Alyssa, Begonia &amp;
#              </p>
#              <p>
#               Clove Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Bengaluru, 560103,
#              </p>
#              <p>
#               Karnataka, India
#              </p>
#              <p>
#               CIN : U51109KA2012PTC066107
#              </p>
#              <p>
#               Telephone:
#               <a href="tel:18002089898">
#                1800 208 9898
#               </a>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div>
#         <div class="_1DXv5h">
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://seller.flipkart.com/?utm_source=fkwebsite&amp;utm_medium=websitedirect">
#            <span class="_1Dwg_s">
#             Sell On Flipkart
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="https://brands.flipkart.com">
#            <span class="_1Dwg_s">
#             Advertise
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/account/giftcard?otracker=undefined_footer_footer_navlinks">
#            <span class="_1Dwg_s">
#             Gift Cards
#            </span>
#           </a>
#          </div>
#          <div>
#           <img src="data:image/svg+xml;base64,..."/>
#           <a href="/helpcentre?otracker=undefined_footer_footer_navlinks">
#            <span class="_1Dwg_s">
#             Help Center
#            </span>
#           </a>
#          </div>
#          <span class="_2tFDQF">
#           © 2007-
#           <!-- -->
#           2020
#           <!-- -->
#           <span>
#            Flipkart.com
#           </span>
#          </span>
#          <img src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/payment-method_b3ab24.svg"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="_16c-eX _16DdHx">
#      <div class="kxUxS5">
#       <svg class="j43Uvy" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#        <path class="_14b0BE" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#        </path>
#       </svg>
#       <span>
#        Back to top
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="703819325761862535" type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
#   </script>
#   <script id="is_script" nonce="703819325761862535">
#    window.__INITIAL_STATE__ = {"abExperiments":{"autosuggest_cache":{"value":"cache_control_23_july","abId":"5cf539a8"},"ncfv2AB":{"value":true,"abId":"648adaf1"},"matching-control-0406":{"value":true,"abId":"96b04421"},"trackingId":{"value":"matchingControl","abId":"96b04421"},"rankingBucket":{"value":"SS_DVS_IDSale","abId":"a9620b5a"},"detailedPriceSummaryABFkCo":{"value":true,"abId":"b1b55d49"},"enableIcons":{"value":true,"abId":"ecb856e1"},"isRepeatOrderNudgeEnabled":{"value":false,"abId":"f02de934"}},"activateVip":{"asyncStatus":"INIT","widget":[]},"autosuggest":{"query":null,"payloadId":null,"searchHistory":[],"asyncStatus":"INIT","words":{},"searchBrowseHistoryRequest":{}},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncStatus":"INIT","data":{"requestedStores":[]}},"checkoutPage":{"summary":{"asyncStatus":"INIT"},"checkoutAsyncStatus":"INIT","addressCache":{"newAddressForm":{"id":"newAddressForm","name":"","addressLine1":"","addressLine2":"","landmark":"","city":"","state":"","pincode":"","phone":"","alternatePhone":"","locationTypeTag":""}},"visualState":{"login":"EXPANDED","address":"COLLAPSED","orderSummary":"COLLAPSED","payment":"COLLAPSED"},"loginState":{"asyncStatus":"INIT"},"buyNow":{"eids":"","domain":"physical","analytics":{},"quantity":0},"addressLocation":{"asyncStatus":"INIT"}},"claimedReward":{"asyncStatus":"INIT","widget":[]},"compareAddProductData":{"asyncStatus":"INIT","brandvsproduct":{},"brand":null},"compareBrandData":{"asyncStatus":"INIT"},"comparePageData":{"asyncStatus":"INIT","showDifference":false},"compareWidgetData":[],"config":{"asyncStatus":"SUCCESS","data":{"globalConfig":{"deferReco":true,"disableRecentlyViewed":false,"disableReco":false,"disableSearch":false,"disableSeo":false,"enableCLPv4":true,"enableRenderableSnippets":true,"enableSnippetsInSwatches":false,"enableInlineVisualWidget":true,"enableInlineMessageWidget":false,"enableProductPageServerRendering":true,"enableBrowsePageServerRendering":true,"enableHomePageServerRendering":true,"enableCLPServerRendering":true,"enableStreaming":true,"enableAllReviewsPageServerRendering":true,"enablePaymentDegrade":false,"enableYahooPixel":false,"enableCriteo":false,"enableFingerPrint":true,"skipCTARender":false,"enableGroceryV2Experience":true,"enable11x11":false,"enableGroceryV2Experience_test":true,"enableNewProductTitle":true,"enableStickyBasketV2":true,"enableMWFrameworkForProductPage":true,"enableMWFrameworkForCLPPage":false,"enableMWFrameworkForBrowsePage":false,"enableOffersAsSnippets":true,"checkBnplMigration":true,"autoSuggestCacheTTLInMillis":0,"supportHeliosRedirection":true,"enableABBotTracking":false,"enableUPIPayment":true,"enableCryspIntegration":false},"newSupportHeliosFlagForTesting":true,"cobrandedExperience":{"yahoo":{"logo":"https://img1a.flixcart.com/www/promos/new/20161121-160909-yahoo-store.png","class":"yahoo-store","store-link":"https://in.yahoo.com/","store-name":"Go Back to Yahoo.in","tracking-name":"yahoocobr","pixel-tracking-url":"https://sp.analytics.yahoo.com/spp.pl?a=10000&.yp=10021645","search-pixel-url":"https://bat.bing.com/action/0?ti=4003414&Ver=2"},"airtel":{"logo":"http://img5a.flixcart.com/www/promos/new/20150618-144245-header-airtel-white.png","class":"airtel-store","store-link":"www.airtel.in","store-name":"Go Back to Airtel.in","tracking-name":"airtel-cobrand-store"},"axis":{"logo":"https://rukminim1.flixcart.com/www/245/50/promos/02/06/2017/4a815cb2-29f5-4c5b-a5af-a9278feb1a1b.png?q=90","class":"axis-store","store-link":"https://www.axisbank.com","store-name":"Go back to Axis Bank","tracking-name":"axiscobr","footer":"Exclusive Store, for Axis Bank Customers!"},"offers":{"logo":"https://img1a.flixcart.com/www/promos/new/20150618-145909-header-smartbuy-white.png","class":"hdfc-store ","store-link":"www.smartbuy.hdfcbank.com","store-name":"Go Back to Smart buy","tracking-name":"hdfc-cobrand-store","f ...
#   </script>
#   <script nonce="703819325761862535">
#    window.__BUNDLE_IDS__ = {};
#   </script>
#   <script nonce="703819325761862535">
#    window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;
#
# 	if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 			navigator.onLine && navigator.serviceWorker.controller && navigator.serviceWorker.controller.postMessage('BANDWIDTH_COMPUTE');
# 			navigator.serviceWorker.addEventListener('message', function (event) {
# 				try {
# 					const bandwidthData = JSON.parse(event.data);
# 					if (bandwidthData && bandwidthData.data) {
# 						window.bandwidth = bandwidthData.data.downlink + '_' + bandwidthData.data.computeMethod + '_' + bandwidthData.data.effectiveType + '_' + bandwidthData.data.type;
# 					}
# 				}catch(err) {
# 					console.error('JSON.parse failed:', err);
# 				}
# 			});
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }
#   </script>
#   <script async="" defer="" id="omni_script" nonce="703819325761862535" src="//img1a.flixcart.com/www/linchpin/batman-returns/omni/omni16.js">
#   </script>
#  </body>
# </html>

# %%
desc = soup.find_all('div' , class_='_3wU53n') # Extracting the descriptions from the website using the find method - grabbing the div tag which has the classname _3wU53n
# So now this returns all the div tags with the classname of _3wU53n
# As class is a speical keyword in python we have to use the class_ keyword and pass the arguments here
descriptions = []
for i in range(len(desc)):
    descriptions.append(desc[i].text) # We can even access the child tags with dot access.
descriptions
len(descriptions)
# Out:
# 24

# %%
commonclass = soup.find_all('li',class_='tVe95H') # We observe that the classnames for the different specifications are under one div.So we need to apply some method to extract the different features.
 
# Create empty lists for the features
processors=[]
ram=[]
os=[]
storage=[]
inches=[]
warranty=[]

for i in range(0,len(commonclass)):
    p=commonclass[i].text # Extracting the text from the tags
    if("Processor" in p): 
        processors.append(p)
    elif("RAM" in p): # If RAM is present in the text then append it to the ram list. Similarly do this for the other features as well
        ram.append(p)
    elif("HDD" in p or "SSD" in p):
        storage.append(p)
    elif("Operating" in p):
        os.append(p)
    elif("Display" in p):
        inches.append(p)
    elif("Warranty" in p):
        warranty.append(p)

# %%
print(len(processors))
print(len(warranty))
print(len(os))
print(len(ram))
print(len(storage))
print(len(inches)) # We observe that the length of all the features is same which is 24
# Out:
# 24
# 24
# 24
# 24
# 24

# %%
price = soup.find_all('div',class_='_1vC4OE _2rQ-NK') # Extracting price of each laptop from the website
prices = []
for i in range(len(price)):
    prices.append(price[i].text)
prices
len(prices)
# Out:
# 24

# %%
original_price = soup.find_all('div',class_='_3auQ3N _2GcJzG')
len(original_price)
# Out:
# 23

# %%
original_prices = []
for i in range(len(original_price)):
    original_prices.append(original_price[i].text)
original_prices
len(original_prices) # Here we get 23 since there is no original price listed for 1 laptops-this means that there is actually no discount on the laptop and the original price is same as the discounted price
# Out:
# 23

# %%
rating = soup.find_all('div',class_='hGSR34') # Extracting the ratings of all the laptops
ratings = []
for i in range(len(rating)):
    ratings.append(rating[i].text)
ratings
len(ratings) # We observe that the classname for the recommended laptops is also same as the present laptops so that's why it is extracting the ratings of recommned laptops as well
# This is increasing the number of ratings
# Out:
# 39

# %%
ratings
# Out:
# ['4.4',
#  '4.3',
#  '4.5',
#  '4.4',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.8',
#  '4.3',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.5',
#  '4.7',
#  '4.3',
#  '4.6',
#  '4.5',
#  '4.4',
#  '4.2',
#  '4.3',
#  '5',
#  '4',
#  '4.5',
#  '4',
#  '5',
#  '4.3',
#  '1',
#  '5',
#  '4.5',
#  '5',
#  '5',
#  '4.3',
#  '5',
#  '5']

# %%
discount = soup.find_all('span')
discount # There are many span tags, but we need to find only the tags which contain discount
# Out:
# [<span class="_2Ky4Ru">Plus</span>,
#  <span>Cart</span>,
#  <span class="_1QZ6fC _3Lgyp8">Electronics<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">TVs &amp; Appliances<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">Men<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">Women<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">Baby &amp; Kids<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">Home &amp; Furniture<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_1QZ6fC _3Lgyp8">Sports, Books &amp; More<svg class="_3ynUUz" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg"><path class="_3Der3h" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="nsslWl"></span>,
#  <span class="_25Wjx4">Grocery</span>,
#  <span class="_25Wjx4">Flights</span>,
#  <span class="_25Wjx4">Offer Zone</span>,
#  <span>Filters</span>,
#  <span>CATEGORIES</span>,
#  <span><svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="zTtNVt" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span><svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span>,
#  <span>Price</span>,
#  <span class="question">?</span>,
#  <span>18 MORE</span>,
#  <span>12 MORE</span>,
#  <span>Need help?</span>,
#  <span>Help me decide</span>,
#  <span class="_2yAnYN">Showing 1 – 24 of 463 results for "<span>laptops</span>"</span>,
#  <span>laptops</span>,
#  <span class="_3YmFT8">Sort By</span>,
#  <span>Ad</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFMHWEYMWHZJSWMDKPA4_COMFMHWEYMWHZJSW_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>39 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span></span>,
#  <span><span>39 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span>,
#  <span>39 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 7 Reviews</span>,
#  <span>11% off</span>,
#  <span>Ad</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFG9YRSCBM46PCCKPJBI_COMFG9YRSCBM46PC_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>1,316 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 197 Reviews</span></span></span>,
#  <span><span>1,316 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 197 Reviews</span></span>,
#  <span>1,316 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 197 Reviews</span>,
#  <span>13% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFR6AANWZVZM8YICAJ6Z_COMFR6AANWZVZM8Y_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>1,955 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 449 Reviews</span></span></span>,
#  <span><span>1,955 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 449 Reviews</span></span>,
#  <span>1,955 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 449 Reviews</span>,
#  <span>28% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFMCSBD8T53WEJ2ZDSQA_COMFMCSBD8T53WEJ_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>1,271 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 220 Reviews</span></span></span>,
#  <span><span>1,271 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 220 Reviews</span></span>,
#  <span>1,271 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 220 Reviews</span>,
#  <span>3% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFRH6ZFRFUFGYNVBLY8S_COMFRH6ZFRFUFGYN_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>68 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 12 Reviews</span></span></span>,
#  <span><span>68 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 12 Reviews</span></span>,
#  <span>68 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 12 Reviews</span>,
#  <span>3% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFQV98ZWHDFGZ7O1IMVP_COMFQV98ZWHDFGZ7_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>47 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span></span>,
#  <span><span>47 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span>,
#  <span>47 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 7 Reviews</span>,
#  <span>17% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFPCU627WHMGFKGM8PEI_COMFPCU627WHMGFK_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>60 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 11 Reviews</span></span></span>,
#  <span><span>60 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 11 Reviews</span></span>,
#  <span>60 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 11 Reviews</span>,
#  <span>16% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFTYWYGHPSGG3TH17DTD_COMFTYWYGHPSGG3T_"><div class="hGSR34">4.8<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>13 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 2 Reviews</span></span></span>,
#  <span><span>13 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 2 Reviews</span></span>,
#  <span>13 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 2 Reviews</span>,
#  <span>23% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFNEK5GUZHGUV6BEHRAN_COMFNEK5GUZHGUV6_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>170 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 38 Reviews</span></span></span>,
#  <span><span>170 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 38 Reviews</span></span>,
#  <span>170 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 38 Reviews</span>,
#  <span>20% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFEHZWRRK32MG3XMTQCA_COMFEHZWRRK32MG3_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>12,405 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 1,750 Reviews</span></span></span>,
#  <span><span>12,405 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 1,750 Reviews</span></span>,
#  <span>12,405 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 1,750 Reviews</span>,
#  <span>21% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFHHNSVWYK7JQPSV8GEP_COMFHHNSVWYK7JQP_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>65 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 8 Reviews</span></span></span>,
#  <span><span>65 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 8 Reviews</span></span>,
#  <span>65 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 8 Reviews</span>,
#  <span>1% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFKYHFKBJATKVJSWUT8C_COMFKYHFKBJATKVJ_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>129 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 20 Reviews</span></span></span>,
#  <span><span>129 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 20 Reviews</span></span>,
#  <span>129 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 20 Reviews</span>,
#  <span>4% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFSFNVDXG74QXRNWOILU_COMFSFNVDXG74QXR_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>502 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 73 Reviews</span></span></span>,
#  <span><span>502 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 73 Reviews</span></span>,
#  <span>502 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 73 Reviews</span>,
#  <span>2% off</span>,
#  <span>Ad</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFGH6RBUXZBC8SEHX8N0_COMFGH6RBUXZBC8S_"><div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>292 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 41 Reviews</span></span></span>,
#  <span><span>292 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 41 Reviews</span></span>,
#  <span>292 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 41 Reviews</span>,
#  <span>44% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFHKKHVGHUBYHWECG2A3_COMFHKKHVGHUBYHW_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>6,316 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 1,036 Reviews</span></span></span>,
#  <span><span>6,316 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 1,036 Reviews</span></span>,
#  <span>6,316 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 1,036 Reviews</span>,
#  <span>12% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFRH6ZVYFDSBQZNDLPBW_COMFRH6ZVYFDSBQZ_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>9 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 0 Reviews</span></span></span>,
#  <span><span>9 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 0 Reviews</span></span>,
#  <span>9 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 0 Reviews</span>,
#  <span>10% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFSKF9HN9Y5WXMJCSVSS_COMFSKF9HN9Y5WXM_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>34 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span></span>,
#  <span><span>34 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span>,
#  <span>34 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 7 Reviews</span>,
#  <span>2% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFMEFVCJCXDCUFBSIKXI_COMFMEFVCJCXDCUF_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>63 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 11 Reviews</span></span></span>,
#  <span><span>63 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 11 Reviews</span></span>,
#  <span>63 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 11 Reviews</span>,
#  <span>4% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFQV9843QQHXUGXCVMDT_COMFQV9843QQHXUG_"><div class="hGSR34">4.7<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>32 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 5 Reviews</span></span></span>,
#  <span><span>32 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 5 Reviews</span></span>,
#  <span>32 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 5 Reviews</span>,
#  <span>17% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFSKF9TPYHX5YFGP3MJW_COMFSKF9TPYHX5YF_"><div class="hGSR34">4.3<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>88 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 23 Reviews</span></span></span>,
#  <span><span>88 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 23 Reviews</span></span>,
#  <span>88 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 23 Reviews</span>,
#  <span>2% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFSDHFN36SGNM5RWJ0MX_COMFSDHFN36SGNM5_"><div class="hGSR34">4.6<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>9 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 2 Reviews</span></span></span>,
#  <span><span>9 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 2 Reviews</span></span>,
#  <span>9 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 2 Reviews</span>,
#  <span>1% off</span>,
#  <span class="rIHMVr">Coming Soon</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFSFNWVD49FZ5FTE5FTF_COMFSFNWVD49FZ5F_"><div class="hGSR34">4.5<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>49 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 12 Reviews</span></span></span>,
#  <span><span>49 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 12 Reviews</span></span>,
#  <span>49 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 12 Reviews</span>,
#  <span>3% off</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFJHDZDNR6PP2KEDDTKR_COMFJHDZDNR6PP2K_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>63 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span></span>,
#  <span><span>63 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 7 Reviews</span></span>,
#  <span>63 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 7 Reviews</span>,
#  <span class="_1iHA1p"><div class="_2kFyHg"><label><input class="_3uUUD5" readonly="" type="checkbox" value="on"/><div class="_1p7h2j"></div></label></div></span>,
#  <span>Add to Compare</span>,
#  <span class="_2_KrJI" id="productRating_LSTCOMFFY9M2PGZNPGG1DSOKK_COMFFY9M2PGZNPGG_"><div class="hGSR34">4.2<img class="_2lQ_WZ" src="..."/></div></span>,
#  <span class="_38sUEc"><span><span>60 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 15 Reviews</span></span></span>,
#  <span><span>60 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 15 Reviews</span></span>,
#  <span>60 Ratings </span>,
#  <span class="_1VpSqZ">&amp;</span>,
#  <span> 15 Reviews</span>,
#  <span>21% off</span>,
#  <span>Page 1 of 20</span>,
#  <span>Next</span>,
#  <span class="_293mUA"></span>,
#  <span class="EgB3Zj">Did you find what you were looking for?</span>,
#  <span class="_2SL4bA _2ipQ_6">Yes</span>,
#  <span class="_2SL4bA _2ipQ_6">No</span>,
#  <span class="_1SMN2T"><span>170 Ratings</span><span><span class="_2GCkCJ">&amp;</span><span>38 Reviews</span></span></span>,
#  <span>170 Ratings</span>,
#  <span><span class="_2GCkCJ">&amp;</span><span>38 Reviews</span></span>,
#  <span class="_2GCkCJ">&amp;</span>,
#  <span>38 Reviews</span>,
#  <span>20% off</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_2jRR3v"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_1SMN2T"><span>63 Ratings</span><span><span class="_2GCkCJ">&amp;</span><span>11 Reviews</span></span></span>,
#  <span>63 Ratings</span>,
#  <span><span class="_2GCkCJ">&amp;</span><span>11 Reviews</span></span>,
#  <span class="_2GCkCJ">&amp;</span>,
#  <span>11 Reviews</span>,
#  <span>4% off</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_2jRR3v"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_1SMN2T"><span>129 Ratings</span><span><span class="_2GCkCJ">&amp;</span><span>20 Reviews</span></span></span>,
#  <span>129 Ratings</span>,
#  <span><span class="_2GCkCJ">&amp;</span><span>20 Reviews</span></span>,
#  <span class="_2GCkCJ">&amp;</span>,
#  <span>20 Reviews</span>,
#  <span>4% off</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_1SMN2T"><span>1,955 Ratings</span><span><span class="_2GCkCJ">&amp;</span><span>449 Reviews</span></span></span>,
#  <span>1,955 Ratings</span>,
#  <span><span class="_2GCkCJ">&amp;</span><span>449 Reviews</span></span>,
#  <span class="_2GCkCJ">&amp;</span>,
#  <span>449 Reviews</span>,
#  <span>28% off</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_2jRR3v"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_1SMN2T"><span>1,316 Ratings</span><span><span class="_2GCkCJ">&amp;</span><span>197 Reviews</span></span></span>,
#  <span>1,316 Ratings</span>,
#  <span><span class="_2GCkCJ">&amp;</span><span>197 Reviews</span></span>,
#  <span class="_2GCkCJ">&amp;</span>,
#  <span>197 Reviews</span>,
#  <span>13% off</span>,
#  <span class="_1EPkIx"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span class="_2jRR3v"><span>Read full review</span></span>,
#  <span>Read full review</span>,
#  <span>Certified Buyer</span>,
#  <span>Mail Us:</span>,
#  <span>Registered Office Address:</span>,
#  <span class="_1Dwg_s">Sell On Flipkart</span>,
#  <span class="_1Dwg_s">Advertise</span>,
#  <span class="_1Dwg_s">Gift Cards</span>,
#  <span class="_1Dwg_s">Help Center</span>,
#  <span class="_2tFDQF">© 2007-<!-- -->2020<!-- --> <span>Flipkart.com</span></span>,
#  <span>Flipkart.com</span>,
#  <span>Back to top</span>]

# %%
discounts = []
for i in range(0,len(discount)):
    p=discount[i].text
    if("% off" in p): # Extracting the tags which contain the discount(all the discounts contain % off so checking with that condition we obtain all the laptops which have discounts)
        discounts.append(p)
discounts
len(discounts)
# Out:
# 28

# %%
discounts
# Out:
# ['11% off',
#  '13% off',
#  '28% off',
#  '3% off',
#  '3% off',
#  '17% off',
#  '16% off',
#  '23% off',
#  '20% off',
#  '21% off',
#  '1% off',
#  '4% off',
#  '2% off',
#  '44% off',
#  '12% off',
#  '10% off',
#  '2% off',
#  '4% off',
#  '17% off',
#  '2% off',
#  '1% off',
#  '3% off',
#  '21% off',
#  '20% off',
#  '4% off',
#  '4% off',
#  '28% off',
#  '13% off']

# %%
d = {'Description':descriptions,'Processor':processors,'RAM':ram,'Operating System':os,'Storage':storage,'Display':inches,'Warranty':warranty,'Price':prices}
dataset = pd.DataFrame(data = d) # Finally merging all the features into a single dataframe

# %%
dataset
# Out:
#                                           Description  ...      Price
# 0   HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...  ...  ₹1,02,990
# 1   Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...  ...    ₹55,990
# 2   Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...  ...    ₹56,990
# 3   Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...  ...    ₹42,990
# 4   HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...  ...    ₹52,990
# 5   Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...    ₹59,990
# 6   Asus VivoBook Gaming Core i5 9th Gen - (8 GB/1...  ...    ₹64,990
# 7   Asus ROG Strix G15 Core i7 10th Gen - (8 GB/1 ...  ...    ₹94,990
# 8   Asus VivoBook Gaming Core i7 9th Gen - (16 GB ...  ...    ₹75,990
# 9   Asus VivoBook S Series Core i5 8th Gen - (8 GB...  ...    ₹53,990
# 10  HP Pavilion x360 14 Core i3 10th Gen - (4 GB/2...  ...    ₹50,990
# 11  Dell G3 Core i7 9th Gen - (8 GB/1 TB HDD/512 G...  ...    ₹84,990
# 12  HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1...  ...    ₹54,990
# 13  Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SS...  ...    ₹47,990
# 14  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...    ₹54,990
# 15  Lenovo Thinkpad E14 Core i5 10th Gen - (8 GB/1...  ...    ₹59,990
# 16  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...    ₹52,990
# 17  HP 14s Ryzen 5 Quad Core 3rd Gen - (8 GB/1 TB ...  ...    ₹46,990
# 18  Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...    ₹59,990
# 19  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...    ₹52,990
# 20  HP 14s Core i5 10th Gen - (8 GB/1 TB HDD/256 G...  ...    ₹63,990
# 21  MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...  ...    ₹60,990
# 22  Asus Core i5 8th Gen - (8 GB/512 GB SSD/Window...  ...    ₹59,990
# 23  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...    ₹54,990
#
# [24 rows x 8 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# We go through all the features one by one and keep adding new features. I have made the following changes and created new variables: <br>
# RAM - Made columns for Ram Capacity in GB and the DDR version <br>
# Processor - Made columns for Name of the Processor, Type of the Processor, Generation <br>
# Operating System - Parsed the Operating System from this column and made a new column <br>
# Storage - Made new columns for the type of Disk Drive and the capacity of the Disk Drive <br>
# Display - Made new columns for the size of the laptop(in inches) and touchscreen <br>
# Description - Made new columns for the company and graphic card <br>
# Even the description contains the RAM size,Processor,Storage etc. and we already have seperate features for them.

# %% [markdown]
# # RAM

# %% [markdown]
# ### RAM IN GB

# %%
dataset['ram'] = dataset['RAM'].copy() # Creating a copy of RAM
dataset['ram'].unique()
# Out:
# array(['8 GB DDR4 RAM', '16 GB DDR4 RAM', '4 GB DDR4 RAM',
#        '8 GB DDR3 RAM'], dtype=object)

# %%
dataset['ram']
# Out:
# 0      8 GB DDR4 RAM
# 1      8 GB DDR4 RAM
# 2      8 GB DDR4 RAM
# 3      8 GB DDR4 RAM
# 4      8 GB DDR4 RAM
# 5      8 GB DDR4 RAM
# 6      8 GB DDR4 RAM
# 7      8 GB DDR4 RAM
# 8     16 GB DDR4 RAM
# 9      8 GB DDR4 RAM
# 10     4 GB DDR4 RAM
# 11     8 GB DDR4 RAM
# 12     8 GB DDR4 RAM
# 13     8 GB DDR3 RAM
# 14     8 GB DDR4 RAM
# 15     8 GB DDR4 RAM
# 16     8 GB DDR4 RAM
# 17     8 GB DDR4 RAM
# 18     8 GB DDR4 RAM
# 19     8 GB DDR4 RAM
# 20     8 GB DDR4 RAM
# 21     8 GB DDR4 RAM
# 22     8 GB DDR4 RAM
# 23     8 GB DDR4 RAM
# Name: ram, dtype: object

# %%
ram_in_gb = []
for i in dataset['ram']:
  if(i[0] == '8'): # 8GB RAM
    ram_in_gb.append(i[0])
  elif(i[0] == '4'): # 4GB RAM
    ram_in_gb.append(i[0])
  elif(i[0] == '1'): # 16GB RAM
    ram_in_gb.append('16')
  elif(i[0] == '3'): # 32GB RAM
    ram_in_gb.append('32')
dataset['ram_in_gb'] = ram_in_gb
print(len(ram_in_gb))
dataset['ram_in_gb']
# Out:
# 24
# ['8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '16',
#  '8',
#  '4',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8',
#  '8']

# %% [markdown]
# ### DDR VERSION

# %%
ddr_version = []
for i in dataset['ram']:
    if(i[0] == '8' or i[0] == '4'): # If 4GB or 8GB RAM then check the DDR version
      ddr_version.append(i[8])
    elif(i[0] == '1'):  # If 16GB RAM then check the DDR version
      ddr_version.append(i[9])
    elif(i[0]== '3 '):  # If 32GB RAM then check the DDR version
      ddr_version.append(i[9])
dataset['ddr_version'] = ddr_version
print(len(ddr_version))
dataset['ddr_version']
# Out:
# 24
# ['4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '3',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4']

# %% [markdown]
# # PROCESSOR

# %%
dataset['processor'] = dataset['Processor'].copy() # Creating a copy of Processor
gen = dataset['processor'].apply(lambda x:x.split('(')) # Splitting on '(' so the 2 elements form a list
dataset['processor'].unique()
# Out:
# array(['Intel Core i5 Processor (10th Gen)',
#        'Intel Core i5 Processor (8th Gen)',
#        'Intel Core i5 Processor (9th Gen)',
#        'AMD Ryzen 5 Quad Core Processor (2nd Gen)',
#        'Intel Core i7 Processor (10th Gen)',
#        'Intel Core i7 Processor (9th Gen)',
#        'Intel Core i3 Processor (10th Gen)',
#        'AMD Ryzen 5 Quad Core Processor',
#        'AMD Ryzen 5 Quad Core Processor (3rd Gen)'], dtype=object)

# %%
dataset['processor']
# Out:
# 0            Intel Core i5 Processor (10th Gen)
# 1             Intel Core i5 Processor (8th Gen)
# 2             Intel Core i5 Processor (9th Gen)
# 3     AMD Ryzen 5 Quad Core Processor (2nd Gen)
# 4            Intel Core i5 Processor (10th Gen)
# 5            Intel Core i5 Processor (10th Gen)
# 6             Intel Core i5 Processor (9th Gen)
# 7            Intel Core i7 Processor (10th Gen)
# 8             Intel Core i7 Processor (9th Gen)
# 9             Intel Core i5 Processor (8th Gen)
# 10           Intel Core i3 Processor (10th Gen)
# 11            Intel Core i7 Processor (9th Gen)
# 12              AMD Ryzen 5 Quad Core Processor
# 13            Intel Core i5 Processor (8th Gen)
# 14            Intel Core i5 Processor (8th Gen)
# 15           Intel Core i5 Processor (10th Gen)
# 16           Intel Core i5 Processor (10th Gen)
# 17    AMD Ryzen 5 Quad Core Processor (3rd Gen)
# 18           Intel Core i5 Processor (10th Gen)
# 19           Intel Core i5 Processor (10th Gen)
# 20           Intel Core i5 Processor (10th Gen)
# 21            Intel Core i5 Processor (9th Gen)
# 22            Intel Core i5 Processor (8th Gen)
# 23            Intel Core i5 Processor (8th Gen)
# Name: processor, dtype: object

# %%
gen
# Out:
# 0            [Intel Core i5 Processor , 10th Gen)]
# 1             [Intel Core i5 Processor , 8th Gen)]
# 2             [Intel Core i5 Processor , 9th Gen)]
# 3     [AMD Ryzen 5 Quad Core Processor , 2nd Gen)]
# 4            [Intel Core i5 Processor , 10th Gen)]
# 5            [Intel Core i5 Processor , 10th Gen)]
# 6             [Intel Core i5 Processor , 9th Gen)]
# 7            [Intel Core i7 Processor , 10th Gen)]
# 8             [Intel Core i7 Processor , 9th Gen)]
# 9             [Intel Core i5 Processor , 8th Gen)]
# 10           [Intel Core i3 Processor , 10th Gen)]
# 11            [Intel Core i7 Processor , 9th Gen)]
# 12               [AMD Ryzen 5 Quad Core Processor]
# 13            [Intel Core i5 Processor , 8th Gen)]
# 14            [Intel Core i5 Processor , 8th Gen)]
# 15           [Intel Core i5 Processor , 10th Gen)]
# 16           [Intel Core i5 Processor , 10th Gen)]
# 17    [AMD Ryzen 5 Quad Core Processor , 3rd Gen)]
# 18           [Intel Core i5 Processor , 10th Gen)]
# 19           [Intel Core i5 Processor , 10th Gen)]
# 20           [Intel Core i5 Processor , 10th Gen)]
# 21            [Intel Core i5 Processor , 9th Gen)]
# 22            [Intel Core i5 Processor , 8th Gen)]
# 23            [Intel Core i5 Processor , 8th Gen)]
# Name: processor, dtype: object

# %% [markdown]
# ### PROCESSOR TYPE

# %%
processor_type = []
for i in dataset['processor']:
  if(i[11] == 'i' or i[11] == 'm'):
    processor_type.append(i[11:13])
  elif(i[10] == '5'):
    processor_type.append('Ryzen 5')
  elif(i[10]  == '3'):
    processor_type.append('Ryzen 3')
  elif(i[10] == '7'):
    processor_type.append('Ryzen 7')
  elif('SQ1' in i):
    processor_type.append('SQ1')
  elif('Pentium' in i):
    processor_type.append('Pentium')
  elif('APU' in i):
    processor_type.append('APU')
  elif('Athlon' in i):
    processor_type.append('Athlon')
dataset['processor_type'] = processor_type
print(len(processor_type))
dataset['processor_type']
# Out:
# 24
# 0          i5
# 1          i5
# 2          i5
# 3     Ryzen 5
# 4          i5
# 5          i5
# 6          i5
# 7          i7
# 8          i7
# 9          i5
# 10         i3
# 11         i7
# 12    Ryzen 5
# 13         i5
# 14         i5
# 15         i5
# 16         i5
# 17    Ryzen 5
# 18         i5
# 19         i5
# 20         i5
# 21         i5
# 22         i5
# 23         i5
# Name: processor_type, dtype: object

# %% [markdown]
# ### PROCESSOR NAME

# %%
processor_name = []
for i in dataset['processor']:
  if('Intel' in i): # If it's an Intel processor
    processor_name.append('Intel')
  elif('AMD' in i): # If it's an AMD processor
    processor_name.append('AMD')
  elif('Microsoft' in i): # If it's a Microsoft processor
    processor_name.append('Microsoft')
dataset['processor_name'] = processor_name
print(len(processor_name))
dataset['processor_name']
# Out:
# 24
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel
# 5     Intel
# 6     Intel
# 7     Intel
# 8     Intel
# 9     Intel
# 10    Intel
# 11    Intel
# 12      AMD
# 13    Intel
# 14    Intel
# 15    Intel
# 16    Intel
# 17      AMD
# 18    Intel
# 19    Intel
# 20    Intel
# 21    Intel
# 22    Intel
# 23    Intel
# Name: processor_name, dtype: object

# %% [markdown]
# ### GENERATION

# %%
gen_type = []
for i in gen: # After converting into a list we'll be having 2 elements.
  if(len(i) == 2):  # If there is generation mentioned in the processor 
    if(i[1][0] == '1'): # If 10th gen
      gen_type.append('10') 
    else:  # Other than 10th gen
      gen_type.append(i[1][0])
  else: # If the generation is not mentioned
    gen_type.append('Not Mentioned')
dataset['gen_type'] = gen_type
print(len(gen_type))
dataset['gen_type']
# Out:
# 24

# %% [markdown]
# # OPERATING SYSTEM

# %%
dataset['OS'] = dataset['Operating System'].copy() # Creating a copy of Operating System
dataset['OS'].unique()
# Out:
# array(['64 bit Windows 10 Operating System'], dtype=object)

# %%
dataset['OS']
# Out:
# 0     64 bit Windows 10 Operating System
# 1     64 bit Windows 10 Operating System
# 2     64 bit Windows 10 Operating System
# 3     64 bit Windows 10 Operating System
# 4     64 bit Windows 10 Operating System
# 5     64 bit Windows 10 Operating System
# 6     64 bit Windows 10 Operating System
# 7     64 bit Windows 10 Operating System
# 8     64 bit Windows 10 Operating System
# 9     64 bit Windows 10 Operating System
# 10    64 bit Windows 10 Operating System
# 11    64 bit Windows 10 Operating System
# 12    64 bit Windows 10 Operating System
# 13    64 bit Windows 10 Operating System
# 14    64 bit Windows 10 Operating System
# 15    64 bit Windows 10 Operating System
# 16    64 bit Windows 10 Operating System
# 17    64 bit Windows 10 Operating System
# 18    64 bit Windows 10 Operating System
# 19    64 bit Windows 10 Operating System
# 20    64 bit Windows 10 Operating System
# 21    64 bit Windows 10 Operating System
# 22    64 bit Windows 10 Operating System
# 23    64 bit Windows 10 Operating System
# Name: OS, dtype: object

# %%
OS = []
for i in dataset['OS']:
  if('Windows' in i): # Windows Operating System
    OS.append('Windows')
  elif('Mac' in i):   # Mac Operating System
    OS.append('Mac')
  elif('Linux' in i): # Linux Operating System
    OS.append('Linux')
  elif('DOS' in i):   # DOS Operating System
    OS.append('DOS')
dataset['OS'] = OS
print(len(dataset['OS']))
dataset['OS']
# Out:
# 24
# 0     Windows
# 1     Windows
# 2     Windows
# 3     Windows
# 4     Windows
# 5     Windows
# 6     Windows
# 7     Windows
# 8     Windows
# 9     Windows
# 10    Windows
# 11    Windows
# 12    Windows
# 13    Windows
# 14    Windows
# 15    Windows
# 16    Windows
# 17    Windows
# 18    Windows
# 19    Windows
# 20    Windows
# 21    Windows
# 22    Windows
# 23    Windows
# Name: OS, dtype: object

# %% [markdown]
# # STORAGE

# %% [markdown]
# ### DISK DRIVE

# %%
dataset['storage'] = dataset['Storage'].copy() # Creating a copy of Storage
dataset['storage'].unique()
# Out:
# array(['512 GB SSD', '1 TB HDD|256 GB SSD', '1 TB SSD', '256 GB SSD',
#        '1 TB HDD|512 GB SSD', '1 TB HDD', '1 TB HDD|128 GB SSD'],
#       dtype=object)

# %%
dataset['storage']
# Out:
# 0              512 GB SSD
# 1              512 GB SSD
# 2              512 GB SSD
# 3              512 GB SSD
# 4              512 GB SSD
# 5     1 TB HDD|256 GB SSD
# 6     1 TB HDD|256 GB SSD
# 7                1 TB SSD
# 8              512 GB SSD
# 9     1 TB HDD|256 GB SSD
# 10             256 GB SSD
# 11    1 TB HDD|512 GB SSD
# 12               1 TB HDD
# 13             256 GB SSD
# 14             512 GB SSD
# 15    1 TB HDD|128 GB SSD
# 16             512 GB SSD
# 17    1 TB HDD|256 GB SSD
# 18    1 TB HDD|256 GB SSD
# 19             512 GB SSD
# 20    1 TB HDD|256 GB SSD
# 21             512 GB SSD
# 22             512 GB SSD
# 23             512 GB SSD
# Name: storage, dtype: object

# %%
disk_drive = []
for i in dataset['storage']:
  if('HDD' in i and 'SSD' not in i):   # If only HDD
    disk_drive.append('HDD')
  elif('SSD' in i and 'HDD' not in i): # If only SSD
    disk_drive.append('SSD')
  elif('HDD' in i and 'SSD' in i):     # If both HDD and SSD
    disk_drive.append('Both')
dataset['disk_drive'] = disk_drive
print(len(disk_drive))
dataset['disk_drive']
# Out:
# 24
# 0      SSD
# 1      SSD
# 2      SSD
# 3      SSD
# 4      SSD
# 5     Both
# 6     Both
# 7      SSD
# 8      SSD
# 9     Both
# 10     SSD
# 11    Both
# 12     HDD
# 13     SSD
# 14     SSD
# 15    Both
# 16     SSD
# 17    Both
# 18    Both
# 19     SSD
# 20    Both
# 21     SSD
# 22     SSD
# 23     SSD
# Name: disk_drive, dtype: object

# %% [markdown]
# ### STORAGE IN GB

# %%
storage_in_gb = []
for i in dataset['storage']:
  if('512' in i and 'TB' not in i): # Only 512GB SSD or 512GB HDD
    storage_in_gb.append('512')
  elif('256' in i and 'TB' not in i): # Only 256GB SSD or 256GB HDD
    storage_in_gb.append('256')
  elif('128' in i and 'TB' not in i): # Only 128GB SSD or 128GB HDD
    storage_in_gb.append('128')
  elif('512' in i and 'TB' in i):     # If 1TB HDD + 512GB SSD
    storage_in_gb.append('1000+512')
  elif('256' in i and 'TB' in i):     # If 1TB HDD + 256GB SSD
    storage_in_gb.append('1000+256')
  elif('128' in i and 'TB' in i):     # If 1TB HDD + 128GB SSD
    storage_in_gb.append('1000+128')
  elif('1' in i and '256' not in i and '512' not in i): # Only 1TB HDD or 1TB SSD
    storage_in_gb.append('1000')
  elif('2' in i and '256' not in i and '512' not in i): # Only 2TB HDD or 2TB SSD
    storage_in_gb.append('2000')
dataset['storage_in_gb'] = storage_in_gb
print(len(storage_in_gb))
dataset['storage_in_gb']
# Out:
# 24
# 0          512
# 1          512
# 2          512
# 3          512
# 4          512
# 5     1000+256
# 6     1000+256
# 7         1000
# 8          512
# 9     1000+256
# 10         256
# 11    1000+512
# 12        1000
# 13         256
# 14         512
# 15    1000+128
# 16         512
# 17    1000+256
# 18    1000+256
# 19         512
# 20    1000+256
# 21         512
# 22         512
# 23         512
# Name: storage_in_gb, dtype: object

# %% [markdown]
# # DISPLAY

# %%
dataset['display'] = dataset['Display'].copy() # Creating a copy of Display
dataset['display'].unique()
# Out:
# array(['33.78 cm (13.3 inch) Touchscreen Display',
#        '35.56 cm (14 inch) Display', '39.62 cm (15.6 inch) Display',
#        '35.56 cm (14 inch) Touchscreen Display',
#        '33.78 cm (13.3 inch) Display'], dtype=object)

# %%
dataset['display']
# Out:
# 0     33.78 cm (13.3 inch) Touchscreen Display
# 1                   35.56 cm (14 inch) Display
# 2                 39.62 cm (15.6 inch) Display
# 3                   35.56 cm (14 inch) Display
# 4                   35.56 cm (14 inch) Display
# 5                   35.56 cm (14 inch) Display
# 6                 39.62 cm (15.6 inch) Display
# 7                 39.62 cm (15.6 inch) Display
# 8                 39.62 cm (15.6 inch) Display
# 9                   35.56 cm (14 inch) Display
# 10      35.56 cm (14 inch) Touchscreen Display
# 11                39.62 cm (15.6 inch) Display
# 12                39.62 cm (15.6 inch) Display
# 13                  35.56 cm (14 inch) Display
# 14                  35.56 cm (14 inch) Display
# 15                  35.56 cm (14 inch) Display
# 16                39.62 cm (15.6 inch) Display
# 17                  35.56 cm (14 inch) Display
# 18                  35.56 cm (14 inch) Display
# 19                39.62 cm (15.6 inch) Display
# 20                  35.56 cm (14 inch) Display
# 21                39.62 cm (15.6 inch) Display
# 22                39.62 cm (15.6 inch) Display
# 23                33.78 cm (13.3 inch) Display
# Name: display, dtype: object

# %%
size_in_inches = []
for i in dataset['display']:
  if('15.6' in i):    # If the screen size is 15.6 inches
    size_in_inches.append('15.6')
  elif('14' in i):    # If the screen size is 14 inches
    size_in_inches.append('14')
  elif('13.3' in i):  # If the screen size is 13.3 inches
    size_in_inches.append('13.3')
  elif('13' in i):    # If the screen size is 13 inches
    size_in_inches.append('13')
  elif('13.5' in i):  # If the screen size is 13.5 inches
    size_in_inches.append('13.5')
  elif('17.3' in i):  # If the screen size is 17.3 inches
    size_in_inches.append('17.3')
  elif('16' in i):    # If the screen size is 16 inches
    size_in_inches.append('16')
  elif('10' in i):    # If the screen size is 10 inches
    size_in_inches.append('10')
  elif('15' in i):    # If the screen size is 15 inches
    size_in_inches.append('15')
dataset['size_in_inches'] = size_in_inches
print(len(size_in_inches))
dataset['size_in_inches']
# Out:
# 24
# 0     13.3
# 1       14
# 2     15.6
# 3       14
# 4       14
# 5       14
# 6     15.6
# 7     15.6
# 8     15.6
# 9       14
# 10      14
# 11    15.6
# 12    15.6
# 13      14
# 14      14
# 15      14
# 16    15.6
# 17      14
# 18      14
# 19    15.6
# 20      14
# 21    15.6
# 22    15.6
# 23    13.3
# Name: size_in_inches, dtype: object

# %% [markdown]
# ### TOUCHSCREEN

# %%
touchscreen = []
for i in dataset['display']:
  if('Touchscreen' in i):     # If touchscreen is present
    touchscreen.append('Yes')
  else:
    touchscreen.append('No')  # If there's no touchscreen option
dataset['touchscreen'] = touchscreen
print(len(touchscreen))
dataset['touchscreen']
# Out:
# 24
# 0     Yes
# 1      No
# 2      No
# 3      No
# 4      No
# 5      No
# 6      No
# 7      No
# 8      No
# 9      No
# 10    Yes
# 11     No
# 12     No
# 13     No
# 14     No
# 15     No
# 16     No
# 17     No
# 18     No
# 19     No
# 20     No
# 21     No
# 22     No
# 23     No
# Name: touchscreen, dtype: object

# %% [markdown]
# # DESCRIPTION

# %%
dataset['description'] = dataset['Description'].copy() # Creating a copy of Description
dataset['description'].unique # All the laptops are unique
# dataset['description']
# Out:
# <bound method Series.unique of 0     HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...
# 1     Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 2     Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...
# 3     Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...
# 4     HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...
# 5     Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...
# 6     Asus VivoBook Gaming Core i5 9th Gen - (8 GB/1...
# 7     Asus ROG Strix G15 Core i7 10th Gen - (8 GB/1 ...
# 8     Asus VivoBook Gaming Core i7 9th Gen - (16 GB ...
# 9     Asus VivoBook S Series Core i5 8th Gen - (8 GB...
# 10    HP Pavilion x360 14 Core i3 10th Gen - (4 GB/2...
# 11    Dell G3 Core i7 9th Gen - (8 GB/1 TB HDD/512 G...
# 12    HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1...
# 13    Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SS...
# 14    Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...
# 15    Lenovo Thinkpad E14 Core i5 10th Gen - (8 GB/1...
# 16    Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...
# 17    HP 14s Ryzen 5 Quad Core 3rd Gen - (8 GB/1 TB ...
# 18    Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...
# 19    Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...
# 20    HP 14s Core i5 10th Gen - (8 GB/1 TB HDD/256 G...
# 21    MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...
# 22    Asus Core i5 8th Gen - (8 GB/512 GB SSD/Window...
# 23    Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...
# Name: description, dtype: object>

# %% [markdown]
# ### COMPANY

# %%
company = []
for i in dataset['description']:
  if('Dell' in i):            # If its a Dell laptop
    company.append('Dell')
  elif('Asus' in i):          # If its an Asus laptop
    company.append('Asus')
  elif('Lenovo' in i):        # If its a Lenovo laptop
    company.append('Lenovo')
  elif('Acer' in i):          # If its an Acer laptop
    company.append('Acer')
  elif('HP' in i):            # If its a HP laptop
    company.append('HP')
  elif('Apple' in i):         # If its an Apple laptop
    company.append('Apple')
  elif('MSI' in i):           # If its a MSI laptop
    company.append('MSI')
  elif('Avita' in i):         # If its an Avita laptop
    company.append('Avita')
dataset['company'] = company
print(len(company))
dataset['company']
# Out:
# 24
# 0         HP
# 1       Asus
# 2       Acer
# 3       Asus
# 4         HP
# 5       Asus
# 6       Asus
# 7       Asus
# 8       Asus
# 9       Asus
# 10        HP
# 11      Dell
# 12        HP
# 13      Asus
# 14      Acer
# 15    Lenovo
# 16      Asus
# 17        HP
# 18      Asus
# 19      Asus
# 20        HP
# 21       MSI
# 22      Asus
# 23      Acer
# Name: company, dtype: object

# %% [markdown]
# ### GRAPHIC CARD

# %%
graphic_card = []
for i in dataset['description']:
  if('Graphics' in i): # If Graphic card is present
    graphic_card.append('Yes')
  else:                # If Graphic card is not present
    graphic_card.append('No')
dataset['graphic_card'] = graphic_card
print(len(graphic_card))
dataset['graphic_card']
# Out:
# 24
# 0      No
# 1     Yes
# 2     Yes
# 3      No
# 4      No
# 5     Yes
# 6     Yes
# 7     Yes
# 8     Yes
# 9      No
# 10     No
# 11    Yes
# 12    Yes
# 13     No
# 14    Yes
# 15     No
# 16    Yes
# 17     No
# 18    Yes
# 19    Yes
# 20     No
# 21    Yes
# 22    Yes
# 23     No
# Name: graphic_card, dtype: object

# %%
dataset
# Out:
#                                           Description  ... graphic_card
# 0   HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...  ...           No
# 1   Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...  ...          Yes
# 2   Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...  ...          Yes
# 3   Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...  ...           No
# 4   HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...  ...           No
# 5   Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...          Yes
# 6   Asus VivoBook Gaming Core i5 9th Gen - (8 GB/1...  ...          Yes
# 7   Asus ROG Strix G15 Core i7 10th Gen - (8 GB/1 ...  ...          Yes
# 8   Asus VivoBook Gaming Core i7 9th Gen - (16 GB ...  ...          Yes
# 9   Asus VivoBook S Series Core i5 8th Gen - (8 GB...  ...           No
# 10  HP Pavilion x360 14 Core i3 10th Gen - (4 GB/2...  ...           No
# 11  Dell G3 Core i7 9th Gen - (8 GB/1 TB HDD/512 G...  ...          Yes
# 12  HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1...  ...          Yes
# 13  Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SS...  ...           No
# 14  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...          Yes
# 15  Lenovo Thinkpad E14 Core i5 10th Gen - (8 GB/1...  ...           No
# 16  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...          Yes
# 17  HP 14s Ryzen 5 Quad Core 3rd Gen - (8 GB/1 TB ...  ...           No
# 18  Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...          Yes
# 19  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...          Yes
# 20  HP 14s Core i5 10th Gen - (8 GB/1 TB HDD/256 G...  ...           No
# 21  MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...  ...          Yes
# 22  Asus Core i5 8th Gen - (8 GB/512 GB SSD/Window...  ...          Yes
# 23  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...           No
#
# [24 rows x 25 columns]

# %% [markdown]
# As we have created many copies of the columns now we drop all those copies.

# %%
dataset.drop(['ram','storage','processor','OS','display','description'],axis=1,inplace=True)

# %%
dataset # This is the final dataset
# Out:
#                                           Description  ... graphic_card
# 0   HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...  ...           No
# 1   Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...  ...          Yes
# 2   Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...  ...          Yes
# 3   Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...  ...           No
# 4   HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...  ...           No
# 5   Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...          Yes
# 6   Asus VivoBook Gaming Core i5 9th Gen - (8 GB/1...  ...          Yes
# 7   Asus ROG Strix G15 Core i7 10th Gen - (8 GB/1 ...  ...          Yes
# 8   Asus VivoBook Gaming Core i7 9th Gen - (16 GB ...  ...          Yes
# 9   Asus VivoBook S Series Core i5 8th Gen - (8 GB...  ...           No
# 10  HP Pavilion x360 14 Core i3 10th Gen - (4 GB/2...  ...           No
# 11  Dell G3 Core i7 9th Gen - (8 GB/1 TB HDD/512 G...  ...          Yes
# 12  HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1...  ...          Yes
# 13  Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SS...  ...           No
# 14  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...          Yes
# 15  Lenovo Thinkpad E14 Core i5 10th Gen - (8 GB/1...  ...           No
# 16  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...          Yes
# 17  HP 14s Ryzen 5 Quad Core 3rd Gen - (8 GB/1 TB ...  ...           No
# 18  Asus VivoBook 14 Core i5 10th Gen - (8 GB/1 TB...  ...          Yes
# 19  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...  ...          Yes
# 20  HP 14s Core i5 10th Gen - (8 GB/1 TB HDD/256 G...  ...           No
# 21  MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...  ...          Yes
# 22  Asus Core i5 8th Gen - (8 GB/512 GB SSD/Window...  ...          Yes
# 23  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  ...           No
#
# [24 rows x 19 columns]

# %% [markdown]
# Export the dataset into a CSV file

# %%
dataset.to_csv('dataset.csv')

# %% [markdown]
# As this is a dynamic website the content keeps on changing! So next time if we try to run the link may be same but the content will be different.

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('final_merged.csv')

# %%
df.shape
# Out:
# (168, 21)

# %%
df.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
df.shape
# Out:
# (168, 20)

# %%
df.head()
# Out:
#                                          Description  \
# 0  HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...
# 1  Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...
# 3  Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...
# 4  HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...
#
#                                    Processor            RAM  \
# 0         Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 1          Intel Core i5 Processor (8th Gen)  8 GB DDR4 RAM
# 2          Intel Core i5 Processor (9th Gen)  8 GB DDR4 RAM
# 3  AMD Ryzen 5 Quad Core Processor (2nd Gen)  8 GB DDR4 RAM
# 4         Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
#
#                      Operating System     Storage  \
# 0  64 bit Windows 10 Operating System  512 GB SSD
# 1  64 bit Windows 10 Operating System  512 GB SSD
# 2  64 bit Windows 10 Operating System  512 GB SSD
# 3  64 bit Windows 10 Operating System  512 GB SSD
# 4  64 bit Windows 10 Operating System  512 GB SSD
#
#                                     Display  \
# 0  33.78 cm (13.3 inch) Touchscreen Display
# 1                35.56 cm (14 inch) Display
# 2              39.62 cm (15.6 inch) Display
# 3                35.56 cm (14 inch) Display
# 4                35.56 cm (14 inch) Display
#
#                                          Warranty      Price  RAM_GB  \
# 0                          1 Year Onsite Warranty  ₹1,02,990       8
# 1  1 Year Limited International Hardware Warranty    ₹55,990       8
# 2   1 Year International Travelers Warranty (ITW)    ₹56,990       8
# 3  1 Year Limited International Hardware Warranty    ₹42,990       8
# 4                          1 Year Onsite Warranty    ₹52,990       8
#
#   DDR_Version Processor Name Processor Type Generation Operating System Type  \
# 0           4          Intel             i5         10               Windows
# 1           4          Intel             i5          8               Windows
# 2           4          Intel             i5          9               Windows
# 3           4            AMD        Ryzen 5          2               Windows
# 4           4          Intel             i5         10               Windows
#
#   Storage_GB Disk Drive  Size(Inches) Company Graphic Card Touchscreen
# 0        512        SSD          13.3      HP           No         Yes
# 1        512        SSD          14.0    Asus          Yes          No
# 2        512        SSD          15.6    Acer          Yes          No
# 3        512        SSD          14.0    Asus           No          No
# 4        512        SSD          14.0      HP           No          No

# %%
df.dtypes # Checking the datatypes
# Out:
# Description               object
# Processor                 object
# RAM                       object
# Operating System          object
# Storage                   object
# Display                   object
# Warranty                  object
# Price                     object
# RAM_GB                     int64
# DDR_Version               object
# Processor Name            object
# Processor Type            object
# Generation                object
# Operating System Type     object
# Storage_GB                object
# Disk Drive                object
# Size(Inches)             float64
# Company                   object
# Graphic Card              object
# Touchscreen               object
# dtype: object

# %% [markdown]
# There are a few columns which are categorical here but they actually contain numerical values.So we need to convert few categorical columns to numerical columns. These are DDR_Version,Generation,Storage_GB,Price.

# %%
df['Generation'].unique()
# Out:
# array(['10', '8', '9', '2', 'Not Mentioned', '3', '5', '7'], dtype=object)

# %%
df['DDR_Version'].unique()
# Out:
# array(['4', '3', 'Not Mentioned'], dtype=object)

# %%
df['Storage_GB'].unique()
# Out:
# array(['512', '1000+256', '1000', '256', '1000+128', '128', '1000+512',
#        '2000', '2000+256'], dtype=object)

# %%
# Replacing 'Not Mentioned' with 0
df['Generation']=df['Generation'].apply(lambda x:x.replace('Not Mentioned','0'))
df['DDR_Version']=df['DDR_Version'].apply(lambda x:x.replace('Not Mentioned','0'))

# %%
df['Generation'].unique()
# Out:
# array(['10', '8', '9', '2', '0', '3', '5', '7'], dtype=object)

# %%
df['DDR_Version'].unique()
# Out:
# array(['4', '3', '0'], dtype=object)

# %%
df['RAM'].unique()
# Out:
# array(['8 GB DDR4 RAM', '16 GB DDR4 RAM', '4 GB DDR4 RAM',
#        '8 GB DDR3 RAM', '16 GB LPDDR4X RAM', '8 GB LPDDR4X RAM',
#        '8GB RAM & 256GB SSD for superfast computing', '32 GB DDR4 RAM',
#        '4 GB DDR3 RAM', '16 GB DDR3 RAM'], dtype=object)

# %%
df['RAM']=df['RAM'].apply(lambda x:x.replace('8GB RAM & 256GB SSD for superfast computing','8 GB RAM'))
# Here they have not mentioned the DDR version so we just replace it with 8 GB RAM

# %%
df['RAM'].unique()
# Out:
# array(['8 GB DDR4 RAM', '16 GB DDR4 RAM', '4 GB DDR4 RAM',
#        '8 GB DDR3 RAM', '16 GB LPDDR4X RAM', '8 GB LPDDR4X RAM',
#        '8 GB RAM', '32 GB DDR4 RAM', '4 GB DDR3 RAM', '16 GB DDR3 RAM'],
#       dtype=object)

# %%
df['Storage_GB'].unique()
# Out:
# array(['512', '1000+256', '1000', '256', '1000+128', '128', '1000+512',
#        '2000', '2000+256'], dtype=object)

# %%
df['Storage']
# Out:
# 0               512 GB SSD
# 1               512 GB SSD
# 2               512 GB SSD
# 3               512 GB SSD
# 4               512 GB SSD
#               ...
# 163             128 GB SSD
# 164    2 TB HDD|256 GB SSD
# 165             512 GB SSD
# 166               1 TB SSD
# 167             512 GB SSD
# Name: Storage, Length: 168, dtype: object

# %%
df['Storage'].unique()
# Out:
# array(['512 GB SSD', '1 TB HDD|256 GB SSD', '1 TB SSD', '256 GB SSD',
#        '1 TB HDD|512 GB SSD', '1 TB HDD', '1 TB HDD|128 GB SSD',
#        '128 GB SSD', '2 TB HDD|256 GB SSD',
#        'HP Audio Switch, HP Support Assistant, HP Documentation, HP Jumpstart, HP BIOS Recovery, HP Connection Optimizer, HP 3D DriveGuard (HDD Only), Dropbox',
#        '512 GB SSD for Reduced Boot Up Time and in Game Loading',
#        '1 TB HDD|1 TB SSD', '2 TB HDD'], dtype=object)

# %%
df['Storage']=df['Storage'].apply(lambda x:x.replace('HP Audio Switch, HP Support Assistant, HP Documentation, HP Jumpstart, HP BIOS Recovery, HP Connection Optimizer, HP 3D DriveGuard (HDD Only), Dropbox','1 TB HDD'))
# As they have not mentioned anything about the storage capacity and have mentioned HDD only so we assume the storage as 1 TB HDD

# %%
df['Storage']=df['Storage'].apply(lambda x:x.replace('512 GB SSD for Reduced Boot Up Time and in Game Loading','512 GB SSD'))
# Here its clearly mentioned as 512 GB SSD so we remove the extra part which is Reduced Boot UPp Time...

# %%
df['Storage'].unique()
# Out:
# array(['512 GB SSD', '1 TB HDD|256 GB SSD', '1 TB SSD', '256 GB SSD',
#        '1 TB HDD|512 GB SSD', '1 TB HDD', '1 TB HDD|128 GB SSD',
#        '128 GB SSD', '2 TB HDD|256 GB SSD', '1 TB HDD|1 TB SSD',
#        '2 TB HDD'], dtype=object)

# %%
# Splitting the Storage column into HDD and SSD
SSD = []
HDD = []
def process(inp):
  c = inp.split('|')
  if(len(c) == 1):
    if('SSD' in inp):
      SSD.append(inp)
      HDD.append('0')
    else:
      SSD.append(inp)
      HDD.append('0')
  else:
    SSD.append(c[1])
    HDD.append(c[0])

# %%
for i in df['Storage']:
  process(i)
df['SSD'] = SSD
df['HDD'] = HDD

# %%
df['SSD'].unique() # Have to change this a bit
# Out:
# array(['512 GB SSD', '256 GB SSD', '1 TB SSD', '1 TB HDD', '128 GB SSD',
#        '2 TB HDD'], dtype=object)

# %%
df['HDD'].unique()
# Out:
# array(['0', '1 TB HDD', '2 TB HDD'], dtype=object)

# %%
# Anyways we have 2 columns for HDD and SSD so no need to mention HDD,SSD in the values so we replace the terms HDD,SSD in the values
df['HDD']=df['HDD'].apply(lambda x:x.replace('TB HDD',''))
hdd=[]
for i in df['HDD']:
    if(i=='0'):
        hdd.append(i)
    elif(i=='1 '):
        i=i.replace('1 ','1000')
        hdd.append(i)
    elif(i=='2 '):
        i=i.replace('2 ','2000')
        hdd.append(i)
df['HDD']=hdd
df['HDD'].unique()
# Out:
# array(['0', '1000', '2000'], dtype=object)

# %%
df['SSD']=df['SSD'].apply(lambda x:x.replace('GB SSD',''))
df['SSD']=df['SSD'].apply(lambda x:x.replace('TB SSD',''))
ssd=[]
for i in df['SSD']:
    if(i=='0'):
        hdd.append(i)
    elif(i=='1 '):
        i=i.replace('1 ','1000')
        hdd.append(i)
    elif(i=='2 '):
        i=i.replace('2 ','2000')
    else:
        ssd.append(i)

# %%
ssd
# Out:
# ['512 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '1 TB HDD',
#  '256 ',
#  '512 ',
#  '128 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '128 ',
#  '256 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '256 ',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '1 TB HDD',
#  '512 ',
#  '1 TB HDD',
#  '128 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '128 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '1 TB HDD',
#  '256 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '128 ',
#  '128 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '256 ',
#  '128 ',
#  '256 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '512 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '1 TB HDD',
#  '1 TB HDD',
#  '1 TB HDD',
#  '1 TB HDD',
#  '256 ',
#  '256 ',
#  '128 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '256 ',
#  '256 ',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '256 ',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '128 ',
#  '128 ',
#  '256 ',
#  '256 ',
#  '512 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '256 ',
#  '256 ',
#  '1 TB HDD',
#  '256 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '128 ',
#  '1 TB HDD',
#  '256 ',
#  '1 TB HDD',
#  '512 ',
#  '1 TB HDD',
#  '256 ',
#  '128 ',
#  '512 ',
#  '512 ',
#  '1 TB HDD',
#  '256 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '512 ',
#  '1 TB HDD',
#  '1 TB HDD',
#  '512 ',
#  '128 ',
#  '512 ',
#  '1 TB HDD',
#  '256 ',
#  '512 ',
#  '128 ',
#  '512 ',
#  '512 ',
#  '2 TB HDD',
#  '1 TB HDD',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '256 ',
#  '512 ',
#  '1 TB HDD',
#  '512 ',
#  '512 ',
#  '512 ',
#  '256 ',
#  '128 ',
#  '256 ',
#  '512 ',
#  '512 ']

# %% [markdown]
# Now we can remove the STORAGE_GB column

# %%
df
# Out:
#                                            Description  \
# 0    HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...
# 1    Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 2    Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...
# 3    Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...
# 4    HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...
# ..                                                 ...
# 163  Lenovo Ideapad Slim APU Dual Core A4 - (4 GB/6...
# 164  Acer Predator Triton 300 Core i7 9th Gen - (8 ...
# 165  Lenovo Yoga 730 Core i5 8th Gen - (8 GB/512 GB...
# 166  Asus ZenBook Core i7 10th Gen - (16 GB/1 TB SS...
# 167  Apple MacBook Pro Core i7 7th Gen - (16 GB/512...
#
#                                      Processor             RAM  \
# 0           Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# 1            Intel Core i5 Processor (8th Gen)   8 GB DDR4 RAM
# 2            Intel Core i5 Processor (9th Gen)   8 GB DDR4 RAM
# 3    AMD Ryzen 5 Quad Core Processor (2nd Gen)   8 GB DDR4 RAM
# 4           Intel Core i5 Processor (10th Gen)   8 GB DDR4 RAM
# ..                                         ...             ...
# 163             AMD APU Dual Core A4 Processor   4 GB DDR4 RAM
# 164          Intel Core i7 Processor (9th Gen)   8 GB DDR4 RAM
# 165          Intel Core i5 Processor (8th Gen)   8 GB DDR4 RAM
# 166         Intel Core i7 Processor (10th Gen)  16 GB DDR4 RAM
# 167          Intel Core i7 Processor (7th Gen)  16 GB DDR3 RAM
#
#                        Operating System              Storage  \
# 0    64 bit Windows 10 Operating System           512 GB SSD
# 1    64 bit Windows 10 Operating System           512 GB SSD
# 2    64 bit Windows 10 Operating System           512 GB SSD
# 3    64 bit Windows 10 Operating System           512 GB SSD
# 4    64 bit Windows 10 Operating System           512 GB SSD
# ..                                  ...                  ...
# 163  64 bit Windows 10 Operating System           128 GB SSD
# 164  64 bit Windows 10 Operating System  2 TB HDD|256 GB SSD
# 165  64 bit Windows 10 Operating System           512 GB SSD
# 166  64 bit Windows 10 Operating System             1 TB SSD
# 167      64 bit Mac OS Operating System           512 GB SSD
#
#                                       Display  \
# 0    33.78 cm (13.3 inch) Touchscreen Display
# 1                  35.56 cm (14 inch) Display
# 2                39.62 cm (15.6 inch) Display
# 3                  35.56 cm (14 inch) Display
# 4                  35.56 cm (14 inch) Display
# ..                                        ...
# 163                35.56 cm (14 inch) Display
# 164              39.62 cm (15.6 inch) Display
# 165  33.78 cm (13.3 inch) Touchscreen Display
# 166              33.78 cm (13.3 inch) Display
# 167              39.12 cm (15.4 inch) Display
#
#                                            Warranty      Price  RAM_GB  \
# 0                            1 Year Onsite Warranty  ₹1,02,990       8
# 1    1 Year Limited International Hardware Warranty    ₹55,990       8
# 2     1 Year International Travelers Warranty (ITW)    ₹56,990       8
# 3    1 Year Limited International Hardware Warranty    ₹42,990       8
# 4                            1 Year Onsite Warranty    ₹52,990       8
# ..                                              ...        ...     ...
# 163                          1 Year Onsite Warranty    ₹20,990       4
# 164   1 Year International Travelers Warranty (ITW)    ₹97,990       8
# 165                          1 Year Onsite Warranty    ₹94,990       8
# 166                          1 Year Onsite Warranty    ₹99,990      16
# 167                                 1 Year Warranty  ₹2,29,990      16
#
#     DDR_Version Processor Name Processor Type Generation  \
# 0             4          Intel             i5         10
# 1             4          Intel             i5          8
# 2             4          Intel             i5          9
# 3             4            AMD        Ryzen 5          2
# 4             4          Intel             i5         10
# ..          ...            ...            ...        ...
# 163           4            AMD            APU          0
# 164           4          Intel             i7          9
# 165           4          Intel             i5          8
# 166           4          Intel             i7         10
# 167           3          Intel             i7          7
#
#     Operating System Type Storage_GB Disk Drive  Size(Inches) Company  \
# 0                 Windows        512        SSD          13.3      HP
# 1                 Windows        512        SSD          14.0    Asus
# 2                 Windows        512        SSD          15.6    Acer
# 3                 Windows        512        SSD          14.0    Asus
# 4                 Windows        512        SSD          14.0      HP
# ..                    ...        ...        ...           ...     ...
# 163               Windows        128        SSD          14.0  Lenovo
# 164               Windows   2000+256       Both          15.6    Acer
# 165               Windows        512        SSD          13.3  Lenovo
# 166               Windows       1000        SSD          13.3    Asus
# 167                   Mac        512        SSD          15.4   Apple
#
#     Graphic Card Touchscreen
# 0             No         Yes
# 1            Yes          No
# 2            Yes          No
# 3             No          No
# 4             No          No
# ..           ...         ...
# 163           No          No
# 164          Yes          No
# 165           No         Yes
# 166           No          No
# 167          Yes          No
#
# [168 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['Description', 'Processor', 'RAM', 'Operating System', 'Storage',
#        'Display', 'Warranty', 'Price', 'RAM_GB', 'DDR_Version',
#        'Processor Name', 'Processor Type', 'Generation',
#        'Operating System Type', 'Storage_GB', 'Disk Drive', 'Size(Inches)',
#        'Company', 'Graphic Card', 'Touchscreen'],
#       dtype='object')

# %%
print(df['Processor Name'].unique())
print(df['Processor Type'].unique())
print(df['Operating System Type'].unique())
print(df['Disk Drive'].unique())
# Out:
# ['Intel' 'AMD' 'Microsoft']
# ['i5' 'Ryzen 5' 'i7' 'i3' 'Ryzen 7' 'Ryzen 3' 'SQ1' 'APU' 'Pentium' 'm3'
#  'i9' 'Athlon']
# ['Windows' 'Mac' 'DOS' 'Linux']
# ['SSD' 'Both' 'HDD']

# %%
print(df['Size(Inches)'].unique())
print(df['Company'].unique())
# Out:
# [13.3 14.  15.6 13.  17.3 16.  10.  15.  12.3 15.4]
# ['HP' 'Asus' 'Acer' 'Dell' 'Lenovo' 'MSI' 'Apple' 'Microsoft' 'MarQ'
#  'Avita' 'Alienware' 'Nexstgo']

# %%
cat_to_num = ['Generation','DDR_Version'] 
df[cat_to_num] = df[cat_to_num].apply(pd.to_numeric,errors='coerce') # Converting the categorical variables to numerical variables

# %%
df.dtypes # We can see that the datatypes of these columns have changed to int64
# Out:
# Description               object
# Processor                 object
# RAM                       object
# Operating System          object
# Storage                   object
# Display                   object
# Warranty                  object
# Price                     object
# RAM_GB                     int64
# DDR_Version                int64
# Processor Name            object
# Processor Type            object
# Generation                 int64
# Operating System Type     object
# Storage_GB                object
# Disk Drive                object
# Size(Inches)             float64
# Company                   object
# Graphic Card              object
# Touchscreen               object
# dtype: object

# %% [markdown]
# So all these are the independent variables and price is the dependent variable.

# %%
df['Price'].dtype
# Out:
# dtype('O')

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('₹',''))

# %%
# for i in df['Price'].split(','):
#     i = float(i) #using float because you don't only have integers
#     print(i)

# %%
price = []
for i in df['Price']:
    i = i.replace(',','')
    i = float(i)
    price.append(i)

# %%
df['Price'] = price
df['Price']
# Out:
# 0      102990.0
# 1       55990.0
# 2       56990.0
# 3       42990.0
# 4       52990.0
#          ...
# 163     20990.0
# 164     97990.0
# 165     94990.0
# 166     99990.0
# 167    229990.0
# Name: Price, Length: 168, dtype: float64

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# For now Price is numeric but without commas,but try some method to have the prices with commas and as an integer

# %%
df.head()
# Out:
#                                          Description  \
# 0  HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...
# 1  Asus VivoBook 14 Core i5 8th Gen - (8 GB/512 G...
# 2  Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...
# 3  Asus VivoBook 14 Ryzen 5 Quad Core 2nd Gen - (...
# 4  HP 14s Core i5 10th Gen - (8 GB/512 GB SSD/Win...
#
#                                    Processor            RAM  \
# 0         Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
# 1          Intel Core i5 Processor (8th Gen)  8 GB DDR4 RAM
# 2          Intel Core i5 Processor (9th Gen)  8 GB DDR4 RAM
# 3  AMD Ryzen 5 Quad Core Processor (2nd Gen)  8 GB DDR4 RAM
# 4         Intel Core i5 Processor (10th Gen)  8 GB DDR4 RAM
#
#                      Operating System     Storage  \
# 0  64 bit Windows 10 Operating System  512 GB SSD
# 1  64 bit Windows 10 Operating System  512 GB SSD
# 2  64 bit Windows 10 Operating System  512 GB SSD
# 3  64 bit Windows 10 Operating System  512 GB SSD
# 4  64 bit Windows 10 Operating System  512 GB SSD
#
#                                     Display  \
# 0  33.78 cm (13.3 inch) Touchscreen Display
# 1                35.56 cm (14 inch) Display
# 2              39.62 cm (15.6 inch) Display
# 3                35.56 cm (14 inch) Display
# 4                35.56 cm (14 inch) Display
#
#                                          Warranty     Price  RAM_GB  \
# 0                          1 Year Onsite Warranty  102990.0       8
# 1  1 Year Limited International Hardware Warranty   55990.0       8
# 2   1 Year International Travelers Warranty (ITW)   56990.0       8
# 3  1 Year Limited International Hardware Warranty   42990.0       8
# 4                          1 Year Onsite Warranty   52990.0       8
#
#    DDR_Version Processor Name Processor Type  Generation  \
# 0            4          Intel             i5          10
# 1            4          Intel             i5           8
# 2            4          Intel             i5           9
# 3            4            AMD        Ryzen 5           2
# 4            4          Intel             i5          10
#
#   Operating System Type Storage_GB Disk Drive  Size(Inches) Company  \
# 0               Windows        512        SSD          13.3      HP
# 1               Windows        512        SSD          14.0    Asus
# 2               Windows        512        SSD          15.6    Acer
# 3               Windows        512        SSD          14.0    Asus
# 4               Windows        512        SSD          14.0      HP
#
#   Graphic Card Touchscreen
# 0           No         Yes
# 1          Yes          No
# 2          Yes          No
# 3           No          No
# 4           No          No

# %%
df.columns
# Out:
# Index(['Description', 'Processor', 'RAM', 'Operating System', 'Storage',
#        'Display', 'Warranty', 'Price', 'RAM_GB', 'DDR_Version',
#        'Processor Name', 'Processor Type', 'Generation',
#        'Operating System Type', 'Storage_GB', 'Disk Drive', 'Size(Inches)',
#        'Company', 'Graphic Card', 'Touchscreen'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Description               object
# Processor                 object
# RAM                       object
# Operating System          object
# Storage                   object
# Display                   object
# Warranty                  object
# Price                    float64
# RAM_GB                     int64
# DDR_Version                int64
# Processor Name            object
# Processor Type            object
# Generation                 int64
# Operating System Type     object
# Storage_GB                object
# Disk Drive                object
# Size(Inches)             float64
# Company                   object
# Graphic Card              object
# Touchscreen               object
# dtype: object

# %%
df['Touchscreen'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.to_csv('changed.csv')
